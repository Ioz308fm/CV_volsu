# %%
import cv2
import numpy as np

def find_colored_shapes(image, min_area=0,):
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower_color = np.array([7, 177, 193])
    upper_color = np.array([255, 255, 255])
    color_mask = cv2.inRange(hsv_image, lower_color, upper_color)
    contours, _ = cv2.findContours(color_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    colored_shapes = []

    for contour in contours:
        area = cv2.contourArea(contour)
        if min_area <= area:
            x, y, w, h = cv2.boundingRect(contour)
            colored_shapes.append((x, y, w, h))

    return colored_shapes

image= cv2.imread('tikva.png')

min_area = 50

results = find_colored_shapes(image, min_area=min_area)
if results:
    print(f"Найдено {len(results)} фигур(ы) с площадью от {min_area} пикселей:")
    for i, result in enumerate(results):
        x, y, w, h = result
        print(f"Фигура {i + 1}: x={x}, y={y}, ширина={w}, высота={h}")
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
else:
    print("Фигуры не найдены.")

cv2.imwrite('find_tikvacolor.jpg',image)
# Out:
# Найдено 3 фигур(ы) с площадью от 50 пикселей:
# Фигура 1: x=433, y=370, ширина=103, высота=87
# Фигура 2: x=238, y=310, ширина=143, высота=131
# Фигура 3: x=242, y=43, ширина=135, высота=98
# True

# %%
import cv2
import numpy as np

def find_colored_shapes(image, min_area=0):
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower_color = np.array([8, 180, 180])
    upper_color = np.array([23, 255, 255])
    color_mask = cv2.inRange(hsv_image, lower_color, upper_color)
    contours, _ = cv2.findContours(color_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    colored_shapes = []
    for contour in contours:
        area = cv2.contourArea(contour)
        if min_area <= area:
            x, y, w, h = cv2.boundingRect(contour)
            # Если площадь контура больше 50, проверяем наличие овалов внутри прямоугольника
            if area > 50:
                roi = image[y:y+h, x:x+w]
                # Переводим в оттенки серого и применяем порог для выделения овалов
                gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
                _, oval_mask = cv2.threshold(gray_roi, 50, 255, cv2.THRESH_BINARY)
                # Ищем контуры овалов
                oval_contours, _ = cv2.findContours(oval_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                # Если овалы найдены и их площадь больше 50, добавляем их координаты и размеры в список
                if oval_contours:
                    for oval_contour in oval_contours:
                        oval_area = cv2.contourArea(oval_contour)
                        if oval_area > 50:
                            oval_x, oval_y, oval_w, oval_h = cv2.boundingRect(oval_contour)
                            colored_shapes.append((x + oval_x, y + oval_y, oval_w, oval_h))
            else:
                colored_shapes.append((x, y, w, h))

    return colored_shapes


image_path = ('tikva2.png')
image = cv2.imread(image_path)
min_contour_area = 5

results = find_colored_shapes(image, min_area=min_contour_area)
if results:
    print(f"Найдено {len(results)} фигур(ы) с площадью от {min_contour_area} пикселей:")
    for i, result in enumerate(results):
        x, y, w, h = result
        print(f"Фигура {i + 1}: x={x}, y={y}, ширина={w}, высота={h}")
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
else:
    print("Фигуры не найдены.")

cv2.imwrite('find_tikva2.jpg',image)
# Out:
# Найдено 387 фигур(ы) с площадью от 5 пикселей:
# Фигура 1: x=147, y=496, ширина=6, высота=3
# Фигура 2: x=90, y=495, ширина=6, высота=4
# Фигура 3: x=99, y=494, ширина=10, высота=5
# Фигура 4: x=627, y=492, ширина=21, высота=7
# Фигура 5: x=449, y=481, ширина=23, высота=18
# Фигура 6: x=0, y=473, ширина=22, высота=18
# Фигура 7: x=635, y=472, ширина=9, высота=7
# Фигура 8: x=247, y=471, ширина=23, высота=21
# Фигура 9: x=645, y=469, ширина=13, высота=18
# Фигура 10: x=59, y=456, ширина=22, высота=21
# Фигура 11: x=531, y=450, ширина=26, высота=36
# Фигура 12: x=551, y=449, ширина=11, высота=9
# Фигура 13: x=628, y=447, ширина=13, высота=11
# Фигура 14: x=83, y=446, ширина=22, высота=19
# Фигура 15: x=142, y=444, ширина=24, высота=24
# Фигура 16: x=608, y=439, ширина=16, высота=12
# Фигура 17: x=510, y=433, ширина=25, высота=18
# Фигура 18: x=676, y=432, ширина=7, высота=7
# Фигура 19: x=684, y=431, ширина=9, высота=9
# Фигура 20: x=151, y=429, ширина=7, высота=3
# Фигура 21: x=117, y=429, ширина=22, высота=17
# Фигура 22: x=68, y=426, ширина=27, высота=21
# Фигура 23: x=170, y=420, ширина=21, высота=19
# Фигура 24: x=0, y=420, ширина=10, высота=13
# Фигура 25: x=257, y=419, ширина=22, высота=21
# Фигура 26: x=611, y=416, ширина=39, высота=22
# Фигура 27: x=235, y=415, ширина=18, высота=17
# Фигура 28: x=666, y=412, ширина=16, высота=6
# Фигура 29: x=533, y=412, ширина=14, высота=10
# Фигура 30: x=220, y=412, ширина=11, высота=5
# Фигура 31: x=423, y=402, ширина=46, высота=45
# Фигура 32: x=162, y=399, ширина=21, высота=19
# Фигура 33: x=35, y=399, ширина=24, высота=18
# Фигура 34: x=532, y=398, ширина=14, высота=11
# Фигура 35: x=253, y=395, ширина=21, высота=19
# Фигура 36: x=685, y=391, ширина=20, высота=15
# Фигура 37: x=498, y=390, ширина=20, высота=18
# Фигура 38: x=88, y=381, ширина=14, высота=13
# Фигура 39: x=0, y=378, ширина=37, высота=21
# Фигура 40: x=607, y=374, ширина=24, высота=19
# Фигура 41: x=679, y=373, ширина=23, высота=16
# Фигура 42: x=118, y=370, ширина=4, высота=4
# Фигура 43: x=160, y=367, ширина=19, высота=16
# Фигура 44: x=0, y=365, ширина=17, высота=12
# Фигура 45: x=508, y=362, ширина=21, высота=15
# Фигура 46: x=254, y=362, ширина=19, высота=15
# Фигура 47: x=19, y=360, ширина=24, высота=17
# Фигура 48: x=112, y=358, ширина=10, высота=12
# Фигура 49: x=190, y=357, ширина=19, высота=20
# Фигура 50: x=605, y=354, ширина=15, высота=10
# Фигура 51: x=430, y=350, ширина=17, высота=17
# Фигура 52: x=100, y=347, ширина=18, высота=16
# Фигура 53: x=180, y=346, ширина=31, высота=17
# Фигура 54: x=582, y=343, ширина=19, высота=14
# Фигура 55: x=427, y=340, ширина=14, высота=7
# Фигура 56: x=260, y=337, ширина=30, высота=22
# Фигура 57: x=654, y=335, ширина=16, высота=11
# Фигура 58: x=442, y=333, ширина=7, высота=15
# Фигура 59: x=498, y=332, ширина=18, высота=13
# Фигура 60: x=212, y=325, ширина=16, высота=12
# Фигура 61: x=32, y=325, ширина=31, высота=29
# Фигура 62: x=673, y=324, ширина=22, высота=26
# Фигура 63: x=239, y=318, ширина=16, высота=12
# Фигура 64: x=419, y=317, ширина=32, высота=15
# Фигура 65: x=460, y=314, ширина=33, высота=14
# Фигура 66: x=645, y=313, ширина=21, высота=16
# Фигура 67: x=117, y=313, ширина=29, высота=14
# Фигура 68: x=507, y=310, ширина=17, высота=15
# Фигура 69: x=563, y=308, ширина=29, высота=14
# Фигура 70: x=25, y=308, ширина=21, высота=14
# Фигура 71: x=190, y=307, ширина=35, высота=14
# Фигура 72: x=533, y=304, ширина=12, высота=7
# Фигура 73: x=53, y=298, ширина=24, высота=13
# Фигура 74: x=135, y=297, ширина=18, высота=13
# Фигура 75: x=38, y=297, ширина=12, высота=5
# Фигура 76: x=223, y=295, ширина=15, высота=13
# Фигура 77: x=645, y=291, ширина=16, высота=10
# Фигура 78: x=561, y=289, ширина=18, высота=13
# Фигура 79: x=195, y=286, ширина=20, высота=16
# Фигура 80: x=265, y=282, ширина=31, высота=37
# Фигура 81: x=0, y=282, ширина=18, высота=24
# Фигура 82: x=640, y=279, ширина=17, высота=11
# Фигура 83: x=695, y=273, ширина=10, высота=8
# Фигура 84: x=558, y=272, ширина=19, высота=18
# Фигура 85: x=496, y=270, ширина=25, высота=16
# Фигура 86: x=72, y=270, ширина=15, высота=10
# Фигура 87: x=624, y=265, ширина=20, высота=14
# Фигура 88: x=76, y=260, ширина=26, высота=11
# Фигура 89: x=546, y=259, ширина=16, высота=10
# Фигура 90: x=411, y=259, ширина=28, высота=30
# Фигура 91: x=18, y=259, ширина=18, высота=9
# Фигура 92: x=486, y=258, ширина=17, высота=10
# Фигура 93: x=210, y=258, ширина=16, высота=11
# Фигура 94: x=131, y=258, ширина=16, высота=11
# Фигура 95: x=566, y=256, ширина=7, высота=7
# Фигура 96: x=151, y=256, ширина=15, высота=18
# Фигура 97: x=1, y=254, ширина=14, высота=9
# Фигура 98: x=90, y=251, ширина=14, высота=8
# Фигура 99: x=684, y=243, ширина=17, высота=10
# Фигура 100: x=23, y=243, ширина=18, высота=9
# Фигура 101: x=646, y=242, ширина=18, высота=11
# Фигура 102: x=214, y=240, ширина=23, высота=16
# Фигура 103: x=541, y=239, ширина=24, высота=16
# Фигура 104: x=475, y=239, ширина=15, высота=9
# Фигура 105: x=616, y=238, ширина=16, высота=11
# Фигура 106: x=597, y=238, ширина=16, высота=10
# Фигура 107: x=155, y=237, ширина=11, высота=5
# Фигура 108: x=88, y=234, ширина=13, высота=10
# Фигура 109: x=615, y=232, ширина=10, высота=6
# Фигура 110: x=666, y=231, ширина=10, высота=7
# Фигура 111: x=458, y=230, ширина=16, высота=9
# Фигура 112: x=168, y=230, ширина=8, высота=5
# Фигура 113: x=268, y=228, ширина=34, высота=20
# Фигура 114: x=596, y=224, ширина=17, высота=10
# Фигура 115: x=456, y=223, ширина=10, высота=5
# Фигура 116: x=220, y=223, ширина=13, высота=10
# Фигура 117: x=197, y=222, ширина=12, высота=7
# Фигура 118: x=479, y=221, ширина=11, высота=7
# Фигура 119: x=404, y=219, ширина=30, высота=22
# Фигура 120: x=239, y=218, ширина=12, высота=7
# Фигура 121: x=34, y=218, ширина=19, высота=9
# Фигура 122: x=222, y=217, ширина=10, высота=5
# Фигура 123: x=90, y=217, ширина=30, высота=16
# Фигура 124: x=330, y=213, ширина=39, высота=43
# Фигура 125: x=291, y=213, ширина=12, высота=9
# Фигура 126: x=112, y=213, ширина=14, высота=9
# Фигура 127: x=158, y=211, ширина=31, высота=21
# Фигура 128: x=57, y=211, ширина=10, высота=5
# Фигура 129: x=523, y=208, ширина=29, высота=21
# Фигура 130: x=226, y=208, ширина=13, высота=8
# Фигура 131: x=295, y=205, ширина=13, высота=8
# Фигура 132: x=279, y=205, ширина=14, высота=9
# Фигура 133: x=585, y=204, ширина=16, высота=9
# Фигура 134: x=51, y=202, ширина=12, высота=4
# Фигура 135: x=655, y=201, ширина=16, высота=9
# Фигура 136: x=421, y=199, ширина=14, высота=9
# Фигура 137: x=397, y=199, ширина=17, высота=10
# Фигура 138: x=440, y=196, ширина=6, высота=4
# Фигура 139: x=116, y=195, ширина=15, высота=8
# Фигура 140: x=626, y=194, ширина=12, высота=6
# Фигура 141: x=649, y=193, ширина=14, высота=8
# Фигура 142: x=571, y=192, ширина=15, высота=9
# Фигура 143: x=134, y=190, ширина=12, высота=7
# Фигура 144: x=173, y=189, ширина=14, высота=9
# Фигура 145: x=231, y=188, ширина=9, высота=4
# Фигура 146: x=526, y=186, ширина=14, высота=9
# Фигура 147: x=62, y=186, ширина=10, высота=4
# Фигура 148: x=139, y=183, ширина=11, высота=6
# Фигура 149: x=474, y=182, ширина=7, высота=7
# Фигура 150: x=287, y=182, ширина=22, высота=15
# Фигура 151: x=177, y=181, ширина=13, высота=7
# Фигура 152: x=122, y=181, ширина=14, высота=7
# Фигура 153: x=200, y=180, ширина=31, высота=13
# Фигура 154: x=194, y=178, ширина=15, высота=6
# Фигура 155: x=453, y=177, ширина=17, высота=17
# Фигура 156: x=675, y=176, ширина=24, высота=7
# Фигура 157: x=264, y=176, ширина=15, высота=9
# Фигура 158: x=232, y=176, ширина=21, высота=8
# Фигура 159: x=67, y=176, ширина=23, высота=15
# Фигура 160: x=624, y=171, ширина=15, высота=9
# Фигура 161: x=400, y=171, ширина=24, высота=17
# Фигура 162: x=144, y=169, ширина=8, высота=3
# Фигура 163: x=456, y=168, ширина=14, высота=8
# Фигура 164: x=685, y=167, ширина=10, высота=6
# Фигура 165: x=640, y=167, ширина=13, высота=8
# Фигура 166: x=618, y=167, ширина=12, высота=5
# Фигура 167: x=297, y=166, ширина=5, высота=4
# Фигура 168: x=129, y=166, ширина=14, высота=8
# Фигура 169: x=181, y=165, ширина=17, высота=10
# Фигура 170: x=82, y=159, ширина=11, высота=7
# Фигура 171: x=251, y=158, ширина=7, высота=5
# Фигура 172: x=242, y=157, ширина=6, высота=6
# Фигура 173: x=190, y=157, ширина=17, высота=8
# Фигура 174: x=523, y=155, ширина=9, высота=5
# Фигура 175: x=301, y=155, ширина=11, высота=7
# Фигура 176: x=663, y=154, ширина=8, высота=3
# Фигура 177: x=98, y=154, ширина=9, высота=4
# Фигура 178: x=451, y=151, ширина=10, высота=4
# Фигура 179: x=242, y=150, ширина=12, высота=6
# Фигура 180: x=506, y=149, ширина=6, высота=3
# Фигура 181: x=519, y=145, ширина=10, высота=6
# Фигура 182: x=88, y=145, ширина=14, высота=7
# Фигура 183: x=603, y=143, ширина=15, высота=7
# Фигура 184: x=398, y=142, ширина=21, высота=14
# Фигура 185: x=303, y=142, ширина=11, высота=8
# Фигура 186: x=201, y=141, ширина=8, высота=3
# Фигура 187: x=666, y=140, ширина=9, высота=6
# Фигура 188: x=554, y=138, ширина=22, высота=13
# Фигура 189: x=550, y=138, ширина=7, высота=4
# Фигура 190: x=700, y=137, ширина=5, высота=5
# Фигура 191: x=506, y=136, ширина=6, высота=4
# Фигура 192: x=596, y=135, ширина=15, высота=7
# Фигура 193: x=445, y=134, ширина=12, высота=8
# Фигура 194: x=268, y=132, ширина=9, высота=6
# Фигура 195: x=151, y=132, ширина=25, высота=14
# Фигура 196: x=490, y=131, ширина=11, высота=7
# Фигура 197: x=425, y=131, ширина=10, высота=5
# Фигура 198: x=300, y=131, ширина=12, высота=9
# Фигура 199: x=207, y=130, ширина=15, высота=8
# Фигура 200: x=103, y=130, ширина=22, высота=9
# Фигура 201: x=701, y=129, ширина=4, высота=3
# Фигура 202: x=403, y=128, ширина=9, высота=6
# Фигура 203: x=249, y=128, ширина=18, высота=11
# Фигура 204: x=634, y=126, ширина=6, высота=3
# Фигура 205: x=452, y=126, ширина=19, высота=16
# Фигура 206: x=487, y=125, ширина=7, высота=3
# Фигура 207: x=105, y=124, ширина=11, высота=6
# Фигура 208: x=307, y=123, ширина=11, высота=7
# Фигура 209: x=267, y=122, ширина=11, высота=6
# Фигура 210: x=121, y=122, ширина=11, высота=6
# Фигура 211: x=584, y=120, ширина=9, высота=5
# Фигура 212: x=394, y=118, ширина=21, высота=9
# Фигура 213: x=639, y=117, ширина=15, высота=11
# Фигура 214: x=295, y=117, ширина=16, высота=13
# Фигура 215: x=213, y=117, ширина=5, высота=4
# Фигура 216: x=539, y=116, ширина=19, высота=10
# Фигура 217: x=672, y=114, ширина=7, высота=4
# Фигура 218: x=543, y=114, ширина=8, высота=4
# Фигура 219: x=255, y=113, ширина=14, высота=7
# Фигура 220: x=225, y=111, ширина=9, высота=4
# Фигура 221: x=157, y=111, ширина=10, высота=4
# Фигура 222: x=117, y=111, ширина=11, высота=7
# Фигура 223: x=681, y=110, ширина=19, высота=12
# Фигура 224: x=674, y=109, ширина=10, высота=5
# Фигура 225: x=494, y=109, ширина=5, высота=3
# Фигура 226: x=477, y=109, ширина=10, высота=7
# Фигура 227: x=308, y=108, ширина=9, высота=6
# Фигура 228: x=212, y=108, ширина=11, высота=4
# Фигура 229: x=265, y=106, ширина=8, высота=7
# Фигура 230: x=103, y=106, ширина=11, высота=7
# Фигура 231: x=622, y=103, ширина=16, высота=8
# Фигура 232: x=587, y=103, ширина=10, высота=5
# Фигура 233: x=131, y=103, ширина=9, высота=5
# Фигура 234: x=315, y=102, ширина=7, высота=5
# Фигура 235: x=294, y=102, ширина=10, высота=6
# Фигура 236: x=525, y=100, ширина=24, высота=11
# Фигура 237: x=665, y=96, ширина=11, высота=6
# Фигура 238: x=444, y=96, ширина=10, высота=5
# Фигура 239: x=390, y=96, ширина=19, высота=10
# Фигура 240: x=288, y=95, ширина=8, высота=3
# Фигура 241: x=226, y=95, ширина=9, высота=5
# Фигура 242: x=174, y=95, ширина=19, высота=8
# Фигура 243: x=487, y=92, ширина=8, высота=5
# Фигура 244: x=474, y=92, ширина=5, высота=4
# Фигура 245: x=432, y=92, ширина=12, высота=7
# Фигура 246: x=130, y=92, ширина=19, высота=6
# Фигура 247: x=650, y=90, ширина=18, высота=5
# Фигура 248: x=604, y=90, ширина=20, высота=7
# Фигура 249: x=564, y=89, ширина=8, высота=5
# Фигура 250: x=392, y=88, ширина=8, высота=5
# Фигура 251: x=263, y=88, ширина=6, высота=5
# Фигура 252: x=306, y=86, ширина=8, высота=5
# Фигура 253: x=613, y=85, ширина=8, высота=4
# Фигура 254: x=271, y=84, ширина=9, высота=5
# Фигура 255: x=147, y=84, ширина=11, высота=6
# Фигура 256: x=437, y=83, ширина=4, высота=3
# Фигура 257: x=6, y=83, ширина=24, высота=11
# Фигура 258: x=567, y=81, ширина=6, высота=5
# Фигура 259: x=443, y=81, ширина=5, высота=3
# Фигура 260: x=309, y=81, ширина=8, высота=5
# Фигура 261: x=195, y=81, ширина=5, высота=3
# Фигура 262: x=17, y=81, ширина=6, высота=3
# Фигура 263: x=643, y=80, ширина=8, высота=4
# Фигура 264: x=391, y=80, ширина=15, высота=9
# Фигура 265: x=226, y=80, ширина=7, высота=4
# Фигура 266: x=556, y=79, ширина=9, высота=5
# Фигура 267: x=146, y=79, ширина=5, высота=3
# Фигура 268: x=181, y=77, ширина=9, высота=7
# Фигура 269: x=158, y=77, ширина=6, высота=4
# Фигура 270: x=518, y=76, ширина=20, высота=10
# Фигура 271: x=269, y=76, ширина=13, высота=5
# Фигура 272: x=398, y=75, ширина=7, высота=6
# Фигура 273: x=6, y=75, ширина=11, высота=4
# Фигура 274: x=644, y=74, ширина=6, высота=4
# Фигура 275: x=155, y=73, ширина=4, высота=3
# Фигура 276: x=628, y=72, ширина=13, высота=5
# Фигура 277: x=245, y=72, ширина=7, высота=4
# Фигура 278: x=141, y=72, ширина=8, высота=3
# Фигура 279: x=593, y=67, ширина=15, высота=7
# Фигура 280: x=28, y=67, ширина=18, высота=10
# Фигура 281: x=588, y=66, ширина=7, высота=4
# Фигура 282: x=546, y=66, ширина=9, высота=6
# Фигура 283: x=509, y=66, ширина=9, высота=5
# Фигура 284: x=632, y=64, ширина=7, высота=3
# Фигура 285: x=397, y=63, ширина=6, высота=3
# Фигура 286: x=186, y=63, ширина=8, высота=5
# Фигура 287: x=624, y=62, ширина=6, высота=4
# Фигура 288: x=469, y=62, ширина=5, высота=3
# Фигура 289: x=168, y=62, ширина=6, высота=3
# Фигура 290: x=277, y=61, ширина=8, высота=4
# Фигура 291: x=153, y=61, ширина=11, высота=6
# Фигура 292: x=237, y=60, ширина=13, высота=7
# Фигура 293: x=410, y=59, ширина=8, высота=5
# Фигура 294: x=633, y=58, ширина=7, высота=5
# Фигура 295: x=44, y=58, ширина=15, высота=6
# Фигура 296: x=400, y=57, ширина=6, высота=4
# Фигура 297: x=71, y=57, ширина=8, высота=3
# Фигура 298: x=276, y=55, ширина=5, высота=3
# Фигура 299: x=578, y=54, ширина=10, высота=5
# Фигура 300: x=7, y=54, ширина=8, высота=3
# Фигура 301: x=560, y=53, ширина=7, высота=4
# Фигура 302: x=51, y=53, ширина=5, высота=4
# Фигура 303: x=209, y=52, ширина=6, высота=4
# Фигура 304: x=607, y=50, ширина=5, высота=4
# Фигура 305: x=536, y=50, ширина=6, высота=4
# Фигура 306: x=510, y=50, ширина=5, высота=3
# Фигура 307: x=548, y=49, ширина=5, высота=4
# Фигура 308: x=425, y=49, ширина=5, высота=3
# Фигура 309: x=617, y=48, ширина=8, высота=5
# Фигура 310: x=302, y=48, ширина=7, высота=4
# Фигура 311: x=165, y=48, ширина=10, высота=6
# Фигура 312: x=17, y=48, ширина=8, высота=6
# Фигура 313: x=283, y=47, ширина=5, высота=4
# Фигура 314: x=453, y=46, ширина=5, высота=4
# Фигура 315: x=613, y=45, ширина=8, высота=4
# Фигура 316: x=603, y=45, ширина=9, высота=4
# Фигура 317: x=171, y=45, ширина=11, высота=4
# Фигура 318: x=208, y=43, ширина=7, высота=3
# Фигура 319: x=68, y=43, ширина=8, высота=4
# Фигура 320: x=572, y=41, ширина=6, высота=4
# Фигура 321: x=535, y=41, ширина=7, высота=4
# Фигура 322: x=493, y=41, ширина=8, высота=4
# Фигура 323: x=39, y=41, ширина=11, высота=4
# Фигура 324: x=559, y=40, ширина=7, высота=4
# Фигура 325: x=0, y=40, ширина=8, высота=3
# Фигура 326: x=280, y=39, ширина=12, высота=6
# Фигура 327: x=528, y=37, ширина=6, высота=3
# Фигура 328: x=500, y=37, ширина=5, высота=5
# Фигура 329: x=181, y=37, ширина=6, высота=4
# Фигура 330: x=581, y=36, ширина=4, высота=4
# Фигура 331: x=476, y=35, ширина=5, высота=3
# Фигура 332: x=412, y=35, ширина=7, высота=4
# Фигура 333: x=312, y=35, ширина=7, высота=3
# Фигура 334: x=73, y=34, ширина=13, высота=5
# Фигура 335: x=2, y=34, ширина=13, высота=6
# Фигура 336: x=452, y=32, ширина=8, высота=5
# Фигура 337: x=385, y=32, ширина=6, высота=3
# Фигура 338: x=468, y=31, ширина=6, высота=3
# Фигура 339: x=43, y=31, ширина=8, высота=4
# Фигура 340: x=13, y=31, ширина=8, высота=3
# Фигура 341: x=696, y=29, ширина=8, высота=4
# Фигура 342: x=215, y=29, ширина=7, высота=4
# Фигура 343: x=181, y=27, ширина=14, высота=6
# Фигура 344: x=521, y=26, ширина=10, высота=7
# Фигура 345: x=497, y=26, ширина=5, высота=4
# Фигура 346: x=486, y=26, ширина=12, высота=7
# Фигура 347: x=279, y=26, ширина=9, высота=7
# Фигура 348: x=248, y=26, ширина=6, высота=3
# Фигура 349: x=461, y=24, ширина=6, высота=4
# Фигура 350: x=318, y=24, ширина=5, высота=3
# Фигура 351: x=698, y=23, ширина=6, высота=3
# Фигура 352: x=583, y=23, ширина=7, высота=6
# Фигура 353: x=417, y=23, ширина=7, высота=3
# Фигура 354: x=324, y=23, ширина=5, высота=3
# Фигура 355: x=288, y=23, ширина=7, высота=5
# Фигура 356: x=689, y=21, ширина=8, высота=5
# Фигура 357: x=29, y=21, ширина=6, высота=3
# Фигура 358: x=545, y=19, ширина=7, высота=4
# Фигура 359: x=389, y=19, ширина=4, высота=3
# Фигура 360: x=255, y=19, ширина=10, высота=4
# Фигура 361: x=17, y=19, ширина=11, высота=5
# Фигура 362: x=91, y=18, ширина=14, высота=6
# Фигура 363: x=70, y=18, ширина=7, высота=3
# Фигура 364: x=517, y=17, ширина=4, высота=4
# Фигура 365: x=490, y=16, ширина=5, высота=4
# Фигура 366: x=292, y=15, ширина=5, высота=3
# Фигура 367: x=679, y=14, ширина=7, высота=4
# Фигура 368: x=449, y=13, ширина=5, высота=4
# Фигура 369: x=325, y=13, ширина=5, высота=4
# Фигура 370: x=199, y=12, ширина=5, высота=4
# Фигура 371: x=670, y=10, ширина=6, высота=4
# Фигура 372: x=681, y=9, ширина=4, высота=4
# Фигура 373: x=538, y=9, ширина=6, высота=4
# Фигура 374: x=514, y=9, ширина=5, высота=4
# Фигура 375: x=80, y=9, ширина=7, высота=3
# Фигура 376: x=8, y=8, ширина=15, высота=7
# Фигура 377: x=698, y=7, ширина=7, высота=3
# Фигура 378: x=320, y=7, ширина=5, высота=3
# Фигура 379: x=196, y=6, ширина=9, высота=4
# Фигура 380: x=26, y=5, ширина=7, высота=3
# Фигура 381: x=658, y=4, ширина=6, высота=3
# Фигура 382: x=205, y=4, ширина=6, высота=4
# Фигура 383: x=648, y=1, ширина=9, высота=7
# Фигура 384: x=538, y=1, ширина=5, высота=3
# Фигура 385: x=528, y=1, ширина=9, высота=3
# Фигура 386: x=500, y=1, ширина=9, высота=3
# Фигура 387: x=227, y=1, ширина=4, высота=3
# True
